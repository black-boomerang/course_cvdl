# %% [markdown]
# # Обучение YOLOX (Extra large)
#
# Загружаем необходимые библиотеки:

# %%
import os
import warnings

from config import load_config
from train import train
from utils import convert_anns_to_suit_format

warnings.filterwarnings('ignore')
data_path = r'..\data'
# Out:
# C:\Users\Aleksei\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %% [markdown]
# Обучение будем проводить при помощи библиотеки mmdet. Для начала приведём файл с аннотациями к нужному виду и разобьём выборку на обучение и валидацию:

# %%
convert_anns_to_suit_format(os.path.join(data_path, 'cocotext.v2.json'),
                            os.path.join(data_path, 'cocotext.train.json'),
                            os.path.join(data_path, 'cocotext.val.json'))

# %% [markdown]
# Создаём словарь, в котором названию модели сопоставляется URL предобученной модели (уже есть в репозитории):

# %%
# from utils import get_models_info_file
# get_models_info_file('models_info.json')

# %% [markdown]
# Обучаем модель:

# %%
cfg = load_config('yolox_x_8x8_300e_coco', data_path=data_path)
train(cfg)
# Out:
# loading annotations into memory...
# Done (t=0.57s)
# creating index...
# index created!
# 2022-11-19 11:24:02,573 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# loading annotations into memory...
# 2022-11-19 11:24:02,952 - mmdet - INFO - load checkpoint from local path: C:\Users\Aleksei\course_cvdl\task3\weights\yolox_x_8x8_300e_coco.pth
# Done (t=0.27s)
# creating index...
# index created!
# 2022-11-19 11:24:03,265 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.multi_level_conv_cls.0.weight: copying a param with shape torch.Size([80, 320, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 320, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.0.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for bbox_head.multi_level_conv_cls.1.weight: copying a param with shape torch.Size([80, 320, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 320, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.1.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for bbox_head.multi_level_conv_cls.2.weight: copying a param with shape torch.Size([80, 320, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 320, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# 2022-11-19 11:24:03,294 - mmdet - INFO - Start running, host: Aleksei@DESKTOP-6FN7PTO, work_dir: C:\Users\Aleksei\course_cvdl\task3\workdirs\yolox_x_8x8_300e_coco
# 2022-11-19 11:24:03,295 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) YOLOXLrUpdaterHook
# (49          ) ExpMomentumEMAHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) YOLOXLrUpdaterHook
# (48          ) YOLOXModeSwitchHook
# (48          ) SyncNormHook
# (49          ) ExpMomentumEMAHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) YOLOXLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (49          ) ExpMomentumEMAHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_train_epoch:
# (48          ) SyncNormHook
# (49          ) ExpMomentumEMAHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) TensorboardLoggerHook
#  --------------------
# 2022-11-19 11:24:03,296 - mmdet - INFO - workflow: [('train', 1)], max: 25 epochs
# 2022-11-19 11:24:05,016 - mmdet - INFO - Checkpoints will be saved to C:\Users\Aleksei\course_cvdl\task3\workdirs\yolox_x_8x8_300e_coco by HardDiskBackend.
# 2022-11-19 11:25:03,828 - mmdet - INFO - Epoch [1][100/10922]	lr: 5.001e-06, eta: 1 day, 20:20:38, time: 0.585, data_time: 0.219, memory: 14349, loss_cls: 0.7320, loss_bbox: 3.6076, loss_obj: 9.2557, loss: 13.5952
# 2022-11-20 01:13:17,958 - mmdet - INFO - Epoch [14][400/10922]	lr: 5.000e-06, eta: 11:02:18, time: 0.321, data_time: 0.006, memory: 14553, loss_cls: 0.4550, loss_bbox: 1.6932, loss_obj: 2.9226, loss_l1: 0.4201, loss: 5.4909
# 2022-11-20 01:13:45,803 - mmdet - INFO - Epoch [14][500/10922]	lr: 5.000e-06, eta: 11:01:45, time: 0.278, data_time: 0.005, memory: 14553, loss_cls: 0.4557, loss_bbox: 1.7346, loss_obj: 2.4783, loss_l1: 0.4088, loss: 5.0773
# 2022-11-20 01:14:11,245 - mmdet - INFO - Epoch [14][600/10922]	lr: 5.000e-06, eta: 11:01:10, time: 0.255, data_time: 0.005, memory: 14553, loss_cls: 0.4785, loss_bbox: 1.8208, loss_obj: 2.7185, loss_l1: 0.4505, loss: 5.4683
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 cfg = load_config('yolox_x_8x8_300e_coco', data_path=data_path)
# ----> 2 train(cfg)
#
# File ~\course_cvdl\task3\train.py:14, in train(cfg)
#      12 datasets = [build_dataset(cfg.data.train)]
#      13 model.CLASSES = datasets[0].CLASSES
# ---> 14 train_detector(model, datasets, cfg, distributed=False, validate=True)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\apis\train.py:244, in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     242 elif cfg.load_from:
#     243     runner.load_checkpoint(cfg.load_from)
# --> 244 runner.run(data_loaders, cfg.workflow)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\runner\epoch_based_runner.py:136, in EpochBasedRunner.run(self, data_loaders, workflow, max_epochs, **kwargs)
#     134             if mode == 'train' and self.epoch >= self._max_epochs:
#     135                 break
# --> 136             epoch_runner(data_loaders[i], **kwargs)
#     138 time.sleep(1)  # wait for some hooks like loggers to finish
#     139 self.call_hook('after_run')
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\runner\epoch_based_runner.py:53, in EpochBasedRunner.train(self, data_loader, **kwargs)
#      51 self._inner_iter = i
#      52 self.call_hook('before_train_iter')
# ---> 53 self.run_iter(data_batch, train_mode=True, **kwargs)
#      54 self.call_hook('after_train_iter')
#      55 del self.data_batch
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\runner\epoch_based_runner.py:31, in EpochBasedRunner.run_iter(self, data_batch, train_mode, **kwargs)
#      28     outputs = self.batch_processor(
#      29         self.model, data_batch, train_mode=train_mode, **kwargs)
#      30 elif train_mode:
# ---> 31     outputs = self.model.train_step(data_batch, self.optimizer,
#      32                                     **kwargs)
#      33 else:
#      34     outputs = self.model.val_step(data_batch, self.optimizer, **kwargs)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\parallel\data_parallel.py:77, in MMDataParallel.train_step(self, *inputs, **kwargs)
#      71         raise RuntimeError(
#      72             'module must have its parameters and buffers '
#      73             f'on device {self.src_device_obj} (device_ids[0]) but '
#      74             f'found one of them on device: {t.device}')
#      76 inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 77 return self.module.train_step(*inputs[0], **kwargs[0])
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\detectors\base.py:248, in BaseDetector.train_step(self, data, optimizer)
#     221 def train_step(self, data, optimizer):
#     222     """The iteration step during training.
#     223
#     224     This method defines an iteration step during training, except for the
#    (...)
#     246               averaging the logs.
#     247     """
# --> 248     losses = self(**data)
#     249     loss, log_vars = self._parse_losses(losses)
#     251     outputs = dict(
#     252         loss=loss, log_vars=log_vars, num_samples=len(data['img_metas']))
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\runner\fp16_utils.py:119, in auto_fp16.<locals>.auto_fp16_wrapper.<locals>.new_func(*args, **kwargs)
#     116     raise TypeError('@auto_fp16 can only be used to decorate the '
#     117                     f'method of those classes {supported_types}')
#     118 if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 119     return old_func(*args, **kwargs)
#     121 # get the arg spec of the decorated method
#     122 args_info = getfullargspec(old_func)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\detectors\base.py:172, in BaseDetector.forward(self, img, img_metas, return_loss, **kwargs)
#     169     return self.onnx_export(img[0], img_metas[0])
#     171 if return_loss:
# --> 172     return self.forward_train(img, img_metas, **kwargs)
#     173 else:
#     174     return self.forward_test(img, img_metas, **kwargs)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\detectors\yolox.py:95, in YOLOX.forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore)
#      92 # Multi-scale training
#      93 img, gt_bboxes = self._preprocess(img, gt_bboxes)
# ---> 95 losses = super(YOLOX, self).forward_train(img, img_metas, gt_bboxes,
#      96                                           gt_labels, gt_bboxes_ignore)
#      98 # random resizing
#      99 if (self._progress_in_iter + 1) % self._random_size_interval == 0:
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\detectors\single_stage.py:83, in SingleStageDetector.forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore)
#      81 super(SingleStageDetector, self).forward_train(img, img_metas)
#      82 x = self.extract_feat(img)
# ---> 83 losses = self.bbox_head.forward_train(x, img_metas, gt_bboxes,
#      84                                       gt_labels, gt_bboxes_ignore)
#      85 return losses
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\dense_heads\base_dense_head.py:335, in BaseDenseHead.forward_train(self, x, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, proposal_cfg, **kwargs)
#     333 else:
#     334     loss_inputs = outs + (gt_bboxes, gt_labels, img_metas)
# --> 335 losses = self.loss(*loss_inputs, gt_bboxes_ignore=gt_bboxes_ignore)
#     336 if proposal_cfg is None:
#     337     return losses
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmcv\runner\fp16_utils.py:208, in force_fp32.<locals>.force_fp32_wrapper.<locals>.new_func(*args, **kwargs)
#     205     raise TypeError('@force_fp32 can only be used to decorate the '
#     206                     'method of nn.Module')
#     207 if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 208     return old_func(*args, **kwargs)
#     209 # get the arg spec of the decorated method
#     210 args_info = getfullargspec(old_func)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\dense_heads\yolox_head.py:384, in YOLOXHead.loss(self, cls_scores, bbox_preds, objectnesses, gt_bboxes, gt_labels, img_metas, gt_bboxes_ignore)
#     380 flatten_priors = torch.cat(mlvl_priors)
#     381 flatten_bboxes = self._bbox_decode(flatten_priors, flatten_bbox_preds)
#     383 (pos_masks, cls_targets, obj_targets, bbox_targets, l1_targets,
# --> 384  num_fg_imgs) = multi_apply(
#     385      self._get_target_single, flatten_cls_preds.detach(),
#     386      flatten_objectness.detach(),
#     387      flatten_priors.unsqueeze(0).repeat(num_imgs, 1, 1),
#     388      flatten_bboxes.detach(), gt_bboxes, gt_labels)
#     390 # The experimental results show that ‘reduce_mean’ can improve
#     391 # performance on the COCO dataset.
#     392 num_pos = torch.tensor(
#     393     sum(num_fg_imgs),
#     394     dtype=torch.float,
#     395     device=flatten_cls_preds.device)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\core\utils\misc.py:30, in multi_apply(func, *args, **kwargs)
#      28 pfunc = partial(func, **kwargs) if kwargs else func
#      29 map_results = map(pfunc, *args)
# ---> 30 return tuple(map(list, zip(*map_results)))
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\models\dense_heads\yolox_head.py:464, in YOLOXHead._get_target_single(self, cls_preds, objectness, priors, decoded_bboxes, gt_bboxes, gt_labels)
#     459 # YOLOX uses center priors with 0.5 offset to assign targets,
#     460 # but use center priors without offset to regress bboxes.
#     461 offset_priors = torch.cat(
#     462     [priors[:, :2] + priors[:, 2:] * 0.5, priors[:, 2:]], dim=-1)
# --> 464 assign_result = self.assigner.assign(
#     465     cls_preds.sigmoid() * objectness.unsqueeze(1).sigmoid(),
#     466     offset_priors, decoded_bboxes, gt_bboxes, gt_labels)
#     468 sampling_result = self.sampler.sample(assign_result, priors, gt_bboxes)
#     469 pos_inds = sampling_result.pos_inds
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\core\bbox\assigners\sim_ota_assigner.py:67, in SimOTAAssigner.assign(self, pred_scores, priors, decoded_bboxes, gt_bboxes, gt_labels, gt_bboxes_ignore, eps)
#      46 """Assign gt to priors using SimOTA. It will switch to CPU mode when
#      47 GPU is out of memory.
#      48 Args:
#    (...)
#      64     assign_result (obj:`AssignResult`): The assigned result.
#      65 """
#      66 try:
# ---> 67     assign_result = self._assign(pred_scores, priors, decoded_bboxes,
#      68                                  gt_bboxes, gt_labels,
#      69                                  gt_bboxes_ignore, eps)
#      70     return assign_result
#      71 except RuntimeError:
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\core\bbox\assigners\sim_ota_assigner.py:130, in SimOTAAssigner._assign(self, pred_scores, priors, decoded_bboxes, gt_bboxes, gt_labels, gt_bboxes_ignore, eps)
#     126 # assign 0 by default
#     127 assigned_gt_inds = decoded_bboxes.new_full((num_bboxes, ),
#     128                                            0,
#     129                                            dtype=torch.long)
# --> 130 valid_mask, is_in_boxes_and_center = self.get_in_gt_and_in_center_info(
#     131     priors, gt_bboxes)
#     132 valid_decoded_bbox = decoded_bboxes[valid_mask]
#     133 valid_pred_scores = pred_scores[valid_mask]
#
# File ~\anaconda3\envs\data_science_3.9\lib\site-packages\mmdet\core\bbox\assigners\sim_ota_assigner.py:226, in SimOTAAssigner.get_in_gt_and_in_center_info(self, priors, gt_bboxes)
#     222 is_in_gts_or_centers = is_in_gts_all | is_in_cts_all
#     224 # both in boxes and centers, shape: [num_fg, num_gt]
#     225 is_in_boxes_and_centers = (
# --> 226     is_in_gts[is_in_gts_or_centers, :]
#     227     & is_in_cts[is_in_gts_or_centers, :])
#     228 return is_in_gts_or_centers, is_in_boxes_and_centers
#
# KeyboardInterrupt:
